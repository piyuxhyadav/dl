# %% [markdown]
# 5. Implement the Continuous Bag of Words (CBOW) Model. Stages can be:
# <br>
# a. Data preparation
# <br>
# b. Generate training data
# <br>
# c. Train model
# <br>
# d. Output

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,\
	Embedding, Lambda
from tensorflow.keras.preprocessing.text import Tokenizer
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import re

# %% [markdown]
# #### a. Data preparation

# %%
data = """We are about to study the idea of a computational process.
Computational processes are abstract beings that inhabit computers.
As they evolve, processes manipulate other abstract things called data.
The evolution of a process is directed by a pattern of rules
called a program. People create programs to direct processes. In effect,
we conjure the spirits of the computer with our spells."""

# %%
# for importing data from txt file
# with open("data.txt", "r", encoding="utf-8") as file:
#     data = file.read()

# %%
sentences = data.split(".")

# %%
sentences
# Out:
# ['We are about to study the idea of a computational process',
#  '\nComputational processes are abstract beings that inhabit computers',
#  '\nAs they evolve, processes manipulate other abstract things called data',
#  '\nThe evolution of a process is directed by a pattern of rules\ncalled a program',
#  ' People create programs to direct processes',
#  ' In effect,\nwe conjure the spirits of the computer with our spells',
#  '']

# %%
#Clean Data
clean_sentences = []
for sentence in sentences:
    # skip empty string
    if sentence == "":
        continue;
    # remove special characters
    sentence = re.sub('[^A-Za-z0-9]+', ' ', sentence)
    # remove 1 letter words
    sentence = re.sub(r'(?:^| )\w(?:$| )', ' ', sentence).strip()
    # lower all characters
    sentence = sentence.lower()
    clean_sentences.append(sentence)

# %%
clean_sentences
# Out:
# ['we are about to study the idea of computational process',
#  'computational processes are abstract beings that inhabit computers',
#  'as they evolve processes manipulate other abstract things called data',
#  'the evolution of process is directed by pattern of rules called program',
#  'people create programs to direct processes',
#  'in effect we conjure the spirits of the computer with our spells']

# %%
# Define the corpus
corpus = clean_sentences

# %%
# Convert the corpus to a sequence of integers
tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)
sequences = tokenizer.texts_to_sequences(corpus)
print("After converting our words in the corpus \
into vector of integers:")
print(sequences)
# Out:
# After converting our words in the corpus into vector of integers:
# [[4, 5, 11, 6, 12, 1, 13, 2, 7, 8], [7, 3, 5, 9, 14, 15, 16, 17], [18, 19, 20, 3, 21, 22, 9, 23, 10, 24], [1, 25, 2, 8, 26, 27, 28, 29, 2, 30, 10, 31], [32, 33, 34, 6, 35, 3], [36, 37, 4, 38, 1, 39, 2, 1, 40, 41, 42, 43]]

# %%
# creating dictionary for word to index and index to word
index_to_word_map = {}
word_to_index_map = {}
for index_1, sequence in enumerate(sequences):
    print(sequence)
    words_in_sentence = clean_sentences[index_1].split()
    print(words_in_sentence)
    for index_2, value in enumerate(sequence):
        index_to_word_map[value] = words_in_sentence[index_2]
        word_to_index_map[words_in_sentence[index_2]] = value
# Out:
# [4, 5, 11, 6, 12, 1, 13, 2, 7, 8]
# ['we', 'are', 'about', 'to', 'study', 'the', 'idea', 'of', 'computational', 'process']
# [7, 3, 5, 9, 14, 15, 16, 17]
# ['computational', 'processes', 'are', 'abstract', 'beings', 'that', 'inhabit', 'computers']
# [18, 19, 20, 3, 21, 22, 9, 23, 10, 24]
# ['as', 'they', 'evolve', 'processes', 'manipulate', 'other', 'abstract', 'things', 'called', 'data']
# [1, 25, 2, 8, 26, 27, 28, 29, 2, 30, 10, 31]
# ['the', 'evolution', 'of', 'process', 'is', 'directed', 'by', 'pattern', 'of', 'rules', 'called', 'program']
# [32, 33, 34, 6, 35, 3]
# ['people', 'create', 'programs', 'to', 'direct', 'processes']
# [36, 37, 4, 38, 1, 39, 2, 1, 40, 41, 42, 43]
# ['in', 'effect', 'we', 'conjure', 'the', 'spirits', 'of', 'the', 'computer', 'with', 'our', 'spells']

# %%
print(index_to_word_map)
print("\n")
print(word_to_index_map)
# Out:
# {4: 'we', 5: 'are', 11: 'about', 6: 'to', 12: 'study', 1: 'the', 13: 'idea', 2: 'of', 7: 'computational', 8: 'process', 3: 'processes', 9: 'abstract', 14: 'beings', 15: 'that', 16: 'inhabit', 17: 'computers', 18: 'as', 19: 'they', 20: 'evolve', 21: 'manipulate', 22: 'other', 23: 'things', 10: 'called', 24: 'data', 25: 'evolution', 26: 'is', 27: 'directed', 28: 'by', 29: 'pattern', 30: 'rules', 31: 'program', 32: 'people', 33: 'create', 34: 'programs', 35: 'direct', 36: 'in', 37: 'effect', 38: 'conjure', 39: 'spirits', 40: 'computer', 41: 'with', 42: 'our', 43: 'spells'}
#
#
# {'we': 4, 'are': 5, 'about': 11, 'to': 6, 'study': 12, 'the': 1, 'idea': 13, 'of': 2, 'computational': 7, 'process': 8, 'processes': 3, 'abstract': 9, 'beings': 14, 'that': 15, 'inhabit': 16, 'computers': 17, 'as': 18, 'they': 19, 'evolve': 20, 'manipulate': 21, 'other': 22, 'things': 23, 'called': 10, 'data': 24, 'evolution': 25, 'is': 26, 'directed': 27, 'by': 28, 'pattern': 29, 'rules': 30, 'program': 31, 'people': 32, 'create': 33, 'programs': 34, 'direct': 35, 'in': 36, 'effect': 37, 'conjure': 38, 'spirits': 39, 'computer': 40, 'with': 41, 'our': 42, 'spells': 43}

# %% [markdown]
# #### b. Generate training data

# %%
# Define the parameters
vocab_size = len(tokenizer.word_index) + 1
embedding_size = 10
window_size = 2

# Generate the context-target pairs
contexts = []
targets = []
for sequence in sequences:
	for i in range(window_size, len(sequence) - window_size):
		context = sequence[i - window_size:i] + sequence[i + 1:i + window_size + 1]
		target = sequence[i]
		contexts.append(context)
		targets.append(target)

# %%
# sample of training data
for i in range(5):
    words = []
    target = index_to_word_map.get(targets[i])
    for j in contexts[i]:
        words.append(index_to_word_map.get(j))
    print(words, "=>", target)
# Out:
# ['we', 'are', 'to', 'study'] => about
# ['are', 'about', 'study', 'the'] => to
# ['about', 'to', 'the', 'idea'] => study
# ['to', 'study', 'idea', 'of'] => the
# ['study', 'the', 'of', 'computational'] => idea

# %%
# Convert the contexts and targets to numpy arrays
X = np.array(contexts)
Y = np.array(targets)

# %% [markdown]
# #### c. Train model

# %%
# Define the CBOW model
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=embedding_size, input_length=2 * window_size))
model.add(Lambda(lambda x: tf.reduce_mean(x, axis=1)))
model.add(Dense(256, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(units=vocab_size, activation='softmax'))

# Compile the model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X, Y, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 2/2 [==============================] - 0s 3ms/step - loss: 3.7842 - accuracy: 0.0000e+00
# Epoch 2/200
# 2/2 [==============================] - 0s 2ms/step - loss: 3.7753 - accuracy: 0.1176
# Epoch 3/200
# 2/2 [==============================] - 0s 2ms/step - loss: 3.7686 - accuracy: 0.1176
# Epoch 4/200
# 2/2 [==============================] - 0s 3ms/step - loss: 3.7619 - accuracy: 0.1471
# Epoch 5/200
# 2/2 [==============================] - 0s 2ms/step - loss: 3.7534 - accuracy: 0.1471
# Epoch 6/200
# 2/2 [==============================] - 0s 3ms/step - loss: 3.7430 - accuracy: 0.1471
# Epoch 7/200
# 2/2 [==============================] - 0s 2ms/step - loss: 3.7299 - accuracy: 0.1176
# Epoch 8/200
# 2/2 [==============================] - 0s 3ms/step - loss: 3.7148 - accuracy: 0.1176
# Epoch 9/200
# 2/2 [==============================] - 0s 3ms/step - loss: 3.6958 - accuracy: 0.1176
# Epoch 10/200
# 2/2 [==============================] - 0s 2ms/step - loss: 3.6746 - accuracy: 0.1176
# Epoch 11/200
# 2/2 [==============================] - 0s 2ms/step - loss: 3.6499 - accuracy: 0.1176
# Epoch 12/200
# 2/2 [==============================] - 0s 3ms/step - loss: 3.6217 - accuracy: 0.1176
# Epoch 13/200
# 2/2 [==============================] - 0s 2ms/step - loss: 3.5877 - accuracy: 0.1176
# Epoch 14/200
# 2/2 [==============================] - 0s 3ms/step - loss: 3.5492 - accuracy: 0.1176
# Epoch 15/200
# 2/2 [==============================] - 0s 2ms/step - loss: 3.5069 - accuracy: 0.1176
# Epoch 16/200
# 2/2 [==============================] - 0s 2ms/step - loss: 3.4591 - accuracy: 0.1176
# Epoch 17/200
# 2/2 [==============================] - 0s 3ms/step - loss: 3.4103 - accuracy: 0.1176
# Epoch 18/200
# 2/2 [==============================] - 0s 2ms/step - loss: 3.3624 - accuracy: 0.1176
# Epoch 19/200
# 2/2 [==============================] - 0s 2ms/step - loss: 3.3110 - accuracy: 0.1176
# Epoch 20/200
# 2/2 [==============================] - 0s 2ms/step - loss: 3.2647 - accuracy: 0.1176
# Epoch 21/200
# 2/2 [==============================] - 0s 3ms/step - loss: 3.2192 - accuracy: 0.1176
# Epoch 22/200
# 2/2 [==============================] - 0s 2ms/step - loss: 3.1834 - accuracy: 0.1176
# Epoch 23/200
# 2/2 [==============================] - 0s 2ms/step - loss: 3.1590 - accuracy: 0.1176
# Epoch 24/200
# 2/2 [==============================] - 0s 3ms/step - loss: 3.1381 - accuracy: 0.1176
# Epoch 25/200
# 2/2 [==============================] - 0s 3ms/step - loss: 3.1352 - accuracy: 0.1176
# Epoch 26/200
# 2/2 [==============================] - 0s 3ms/step - loss: 3.1447 - accuracy: 0.1176
# Epoch 27/200
# 2/2 [==============================] - 0s 2ms/step - loss: 3.1325 - accuracy: 0.1176
# Epoch 28/200
# 2/2 [==============================] - 0s 2ms/step - loss: 3.1012 - accuracy: 0.1176
# Epoch 29/200
# 2/2 [==============================] - 0s 2ms/step - loss: 3.0630 - accuracy: 0.1176
# Epoch 30/200
# 2/2 [==============================] - 0s 2ms/step - loss: 3.0305 - accuracy: 0.1176
# Epoch 31/200
# 2/2 [==============================] - 0s 2ms/step - loss: 2.9960 - accuracy: 0.1176
# Epoch 32/200
# 2/2 [==============================] - 0s 2ms/step - loss: 2.9634 - accuracy: 0.1176
# Epoch 33/200
# 2/2 [==============================] - 0s 2ms/step - loss: 2.9312 - accuracy: 0.1471
# Epoch 34/200
# 2/2 [==============================] - 0s 2ms/step - loss: 2.9005 - accuracy: 0.1471
# Epoch 35/200
# 2/2 [==============================] - 0s 2ms/step - loss: 2.8648 - accuracy: 0.1471
# Epoch 36/200
# 2/2 [==============================] - 0s 2ms/step - loss: 2.8237 - accuracy: 0.1471
# Epoch 37/200
# 2/2 [==============================] - 0s 3ms/step - loss: 2.7856 - accuracy: 0.1765
# Epoch 38/200
# 2/2 [==============================] - 0s 2ms/step - loss: 2.7502 - accuracy: 0.1765
# Epoch 39/200
# 2/2 [==============================] - 0s 3ms/step - loss: 2.7204 - accuracy: 0.2059
# Epoch 40/200
# 2/2 [==============================] - 0s 2ms/step - loss: 2.6898 - accuracy: 0.2353
# Epoch 41/200
# 2/2 [==============================] - 0s 3ms/step - loss: 2.6600 - accuracy: 0.2059
# Epoch 42/200
# 2/2 [==============================] - 0s 2ms/step - loss: 2.6344 - accuracy: 0.2059
# Epoch 43/200
# 2/2 [==============================] - 0s 2ms/step - loss: 2.6068 - accuracy: 0.2647
# Epoch 44/200
# 2/2 [==============================] - 0s 3ms/step - loss: 2.5740 - accuracy: 0.2647
# Epoch 45/200
# 2/2 [==============================] - 0s 3ms/step - loss: 2.5443 - accuracy: 0.2647
# Epoch 46/200
# 2/2 [==============================] - 0s 2ms/step - loss: 2.5151 - accuracy: 0.2941
# Epoch 47/200
# 2/2 [==============================] - 0s 3ms/step - loss: 2.4852 - accuracy: 0.2941
# Epoch 48/200
# 2/2 [==============================] - 0s 2ms/step - loss: 2.4528 - accuracy: 0.2941
# Epoch 49/200
# 2/2 [==============================] - 0s 2ms/step - loss: 2.4187 - accuracy: 0.2647
# Epoch 50/200
# 2/2 [==============================] - 0s 3ms/step - loss: 2.3868 - accuracy: 0.2059
# Epoch 51/200
# 2/2 [==============================] - 0s 2ms/step - loss: 2.3561 - accuracy: 0.2059
# Epoch 52/200
# 2/2 [==============================] - 0s 2ms/step - loss: 2.3250 - accuracy: 0.2353
# Epoch 53/200
# 2/2 [==============================] - 0s 2ms/step - loss: 2.2968 - accuracy: 0.2647
# Epoch 54/200
# 2/2 [==============================] - 0s 3ms/step - loss: 2.2696 - accuracy: 0.2941
# Epoch 55/200
# 2/2 [==============================] - 0s 2ms/step - loss: 2.2418 - accuracy: 0.3235
# Epoch 56/200
# 2/2 [==============================] - 0s 2ms/step - loss: 2.2070 - accuracy: 0.3235
# Epoch 57/200
# 2/2 [==============================] - 0s 2ms/step - loss: 2.1650 - accuracy: 0.3529
# Epoch 58/200
# 2/2 [==============================] - 0s 2ms/step - loss: 2.1306 - accuracy: 0.3235
# Epoch 59/200
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0934 - accuracy: 0.3235
# Epoch 60/200
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0656 - accuracy: 0.3235
# Epoch 61/200
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0376 - accuracy: 0.3824
# Epoch 62/200
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0066 - accuracy: 0.4118
# Epoch 63/200
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9703 - accuracy: 0.4118
# Epoch 64/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.9299 - accuracy: 0.4118
# Epoch 65/200
# 2/2 [==============================] - 0s 14ms/step - loss: 1.8883 - accuracy: 0.4412
# Epoch 66/200
# 2/2 [==============================] - 0s 8ms/step - loss: 1.8576 - accuracy: 0.4706
# Epoch 67/200
# 2/2 [==============================] - 0s 4ms/step - loss: 1.8224 - accuracy: 0.4706
# Epoch 68/200
# 2/2 [==============================] - 0s 5ms/step - loss: 1.7920 - accuracy: 0.5588
# Epoch 69/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.7618 - accuracy: 0.4706
# Epoch 70/200
# 2/2 [==============================] - 0s 6ms/step - loss: 1.7362 - accuracy: 0.4412
# Epoch 71/200
# 2/2 [==============================] - 0s 8ms/step - loss: 1.7063 - accuracy: 0.3824
# Epoch 72/200
# 2/2 [==============================] - 0s 8ms/step - loss: 1.6717 - accuracy: 0.3824
# Epoch 73/200
# 2/2 [==============================] - 0s 10ms/step - loss: 1.6458 - accuracy: 0.4118
# Epoch 74/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.6122 - accuracy: 0.4412
# Epoch 75/200
# 2/2 [==============================] - 0s 10ms/step - loss: 1.5933 - accuracy: 0.4412
# Epoch 76/200
# 2/2 [==============================] - 0s 4ms/step - loss: 1.5744 - accuracy: 0.4412
# Epoch 77/200
# 2/2 [==============================] - 0s 2ms/step - loss: 1.5466 - accuracy: 0.4412
# Epoch 78/200
# 2/2 [==============================] - 0s 4ms/step - loss: 1.5211 - accuracy: 0.4706
# Epoch 79/200
# 2/2 [==============================] - 0s 3ms/step - loss: 1.4905 - accuracy: 0.4706
# Epoch 80/200
# 2/2 [==============================] - 0s 2ms/step - loss: 1.4574 - accuracy: 0.5294
# Epoch 81/200
# 2/2 [==============================] - 0s 2ms/step - loss: 1.4235 - accuracy: 0.5588
# Epoch 82/200
# 2/2 [==============================] - 0s 3ms/step - loss: 1.3898 - accuracy: 0.5588
# Epoch 83/200
# 2/2 [==============================] - 0s 2ms/step - loss: 1.3606 - accuracy: 0.5882
# Epoch 84/200
# 2/2 [==============================] - 0s 4ms/step - loss: 1.3322 - accuracy: 0.5882
# Epoch 85/200
# 2/2 [==============================] - 0s 2ms/step - loss: 1.3090 - accuracy: 0.5588
# Epoch 86/200
# 2/2 [==============================] - 0s 2ms/step - loss: 1.2879 - accuracy: 0.5588
# Epoch 87/200
# 2/2 [==============================] - 0s 2ms/step - loss: 1.2665 - accuracy: 0.5000
# Epoch 88/200
# 2/2 [==============================] - 0s 3ms/step - loss: 1.2420 - accuracy: 0.5294
# Epoch 89/200
# 2/2 [==============================] - 0s 2ms/step - loss: 1.2260 - accuracy: 0.5294
# Epoch 90/200
# 2/2 [==============================] - 0s 2ms/step - loss: 1.2038 - accuracy: 0.5882
# Epoch 91/200
# 2/2 [==============================] - 0s 4ms/step - loss: 1.1771 - accuracy: 0.6176
# Epoch 92/200
# 2/2 [==============================] - 0s 5ms/step - loss: 1.1435 - accuracy: 0.6176
# Epoch 93/200
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1075 - accuracy: 0.6765
# Epoch 94/200
# 2/2 [==============================] - 0s 2ms/step - loss: 1.0737 - accuracy: 0.7353
# Epoch 95/200
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0432 - accuracy: 0.7353
# Epoch 96/200
# 2/2 [==============================] - 0s 2ms/step - loss: 1.0216 - accuracy: 0.7353
# Epoch 97/200
# 2/2 [==============================] - 0s 2ms/step - loss: 1.0012 - accuracy: 0.7353
# Epoch 98/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9837 - accuracy: 0.7353
# Epoch 99/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.9621 - accuracy: 0.7647
# Epoch 100/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.9449 - accuracy: 0.7647
# Epoch 101/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.9258 - accuracy: 0.7353
# Epoch 102/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9063 - accuracy: 0.7353
# Epoch 103/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.8917 - accuracy: 0.7647
# Epoch 104/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8627 - accuracy: 0.7647
# Epoch 105/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8362 - accuracy: 0.7647
# Epoch 106/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.8078 - accuracy: 0.8235
# Epoch 107/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.7877 - accuracy: 0.8235
# Epoch 108/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.7820 - accuracy: 0.7647
# Epoch 109/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.7762 - accuracy: 0.7353
# Epoch 110/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.7701 - accuracy: 0.7059
# Epoch 111/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7577 - accuracy: 0.7353
# Epoch 112/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.7442 - accuracy: 0.7353
# Epoch 113/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.7235 - accuracy: 0.7941
# Epoch 114/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7001 - accuracy: 0.7941
# Epoch 115/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.6847 - accuracy: 0.8529
# Epoch 116/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.6685 - accuracy: 0.8235
# Epoch 117/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.6520 - accuracy: 0.8529
# Epoch 118/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6323 - accuracy: 0.8235
# Epoch 119/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6115 - accuracy: 0.8235
# Epoch 120/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.6012 - accuracy: 0.8235
# Epoch 121/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5985 - accuracy: 0.8235
# Epoch 122/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5926 - accuracy: 0.8529
# Epoch 123/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5836 - accuracy: 0.8529
# Epoch 124/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5646 - accuracy: 0.8529
# Epoch 125/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5453 - accuracy: 0.8529
# Epoch 126/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5283 - accuracy: 0.8529
# Epoch 127/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5198 - accuracy: 0.8529
# Epoch 128/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5000 - accuracy: 0.8529
# Epoch 129/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4701 - accuracy: 0.8824
# Epoch 130/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4527 - accuracy: 0.9412
# Epoch 131/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4612 - accuracy: 0.8824
# Epoch 132/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4692 - accuracy: 0.8824
# Epoch 133/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4752 - accuracy: 0.9118
# Epoch 134/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4746 - accuracy: 0.9412
# Epoch 135/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.4704 - accuracy: 0.9412
# Epoch 136/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4631 - accuracy: 0.9412
# Epoch 137/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4574 - accuracy: 0.9412
# Epoch 138/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4532 - accuracy: 0.9118
# Epoch 139/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4497 - accuracy: 0.9118
# Epoch 140/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4422 - accuracy: 0.8824
# Epoch 141/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4299 - accuracy: 0.9118
# Epoch 142/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4102 - accuracy: 0.9118
# Epoch 143/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3854 - accuracy: 0.9412
# Epoch 144/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3656 - accuracy: 0.9412
# Epoch 145/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3475 - accuracy: 0.9412
# Epoch 146/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3328 - accuracy: 0.9706
# Epoch 147/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3230 - accuracy: 0.9706
# Epoch 148/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3187 - accuracy: 0.9706
# Epoch 149/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3114 - accuracy: 0.9706
# Epoch 150/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2994 - accuracy: 0.9706
# Epoch 151/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2826 - accuracy: 0.9706
# Epoch 152/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2696 - accuracy: 0.9706
# Epoch 153/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2575 - accuracy: 0.9706
# Epoch 154/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2471 - accuracy: 0.9706
# Epoch 155/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2403 - accuracy: 0.9706
# Epoch 156/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2408 - accuracy: 0.9412
# Epoch 157/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2433 - accuracy: 0.9412
# Epoch 158/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2484 - accuracy: 0.9412
# Epoch 159/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2517 - accuracy: 0.9412
# Epoch 160/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2506 - accuracy: 0.9412
# Epoch 161/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2448 - accuracy: 0.9412
# Epoch 162/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2333 - accuracy: 0.9412
# Epoch 163/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2208 - accuracy: 0.9412
# Epoch 164/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2098 - accuracy: 0.9412
# Epoch 165/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1994 - accuracy: 0.9412
# Epoch 166/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1904 - accuracy: 0.9706
# Epoch 167/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1825 - accuracy: 1.0000
# Epoch 168/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1792 - accuracy: 0.9706
# Epoch 169/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1843 - accuracy: 0.9706
# Epoch 170/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1925 - accuracy: 0.9412
# Epoch 171/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1973 - accuracy: 0.9412
# Epoch 172/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1966 - accuracy: 0.9412
# Epoch 173/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1922 - accuracy: 0.9412
# Epoch 174/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1856 - accuracy: 0.9412
# Epoch 175/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1784 - accuracy: 0.9706
# Epoch 176/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1681 - accuracy: 0.9706
# Epoch 177/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1587 - accuracy: 0.9706
# Epoch 178/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1496 - accuracy: 0.9706
# Epoch 179/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1419 - accuracy: 0.9706
# Epoch 180/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1399 - accuracy: 0.9706
# Epoch 181/200
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1351 - accuracy: 1.0000
# Epoch 182/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1280 - accuracy: 1.0000
# Epoch 183/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1236 - accuracy: 1.0000
# Epoch 184/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1160 - accuracy: 1.0000
# Epoch 185/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1107 - accuracy: 1.0000
# Epoch 186/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1083 - accuracy: 1.0000
# Epoch 187/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1070 - accuracy: 1.0000
# Epoch 188/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1056 - accuracy: 1.0000
# Epoch 189/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1062 - accuracy: 0.9706
# Epoch 190/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1079 - accuracy: 0.9706
# Epoch 191/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1038 - accuracy: 0.9706
# Epoch 192/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0976 - accuracy: 0.9706
# Epoch 193/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0941 - accuracy: 0.9706
# Epoch 194/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0917 - accuracy: 0.9706
# Epoch 195/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0897 - accuracy: 1.0000
# Epoch 196/200
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0881 - accuracy: 1.0000
# Epoch 197/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0856 - accuracy: 1.0000
# Epoch 198/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0824 - accuracy: 1.0000
# Epoch 199/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0798 - accuracy: 1.0000
# Epoch 200/200
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0778 - accuracy: 1.0000

# %%
# Get the word embeddings
embeddings = model.get_weights()[0]

# Perform PCA to reduce the dimensionality of the embeddings
pca = PCA(n_components=2)
reduced_embeddings = pca.fit_transform(embeddings)

# %% [markdown]
# #### d. Output

# %%
# Visualize the embeddings
plt.figure(figsize=(7, 7))
for i, word in enumerate(tokenizer.word_index.keys()):
    x, y = reduced_embeddings[i]
    plt.scatter(x, y)
    plt.annotate(word, xy=(x, y), xytext=(5, 2),
                 textcoords='offset points',
                 ha='right', va='bottom')
plt.show()

# %%
# test model
test_sentenses = [
    "we are to study",
    "create programs direct processes",
    "spirits process study program",
    "idea study people create"
]

# %%
for test_sentense in test_sentenses:
    test_words = test_sentense.split(" ")
    print("Words: ", test_words)
    x_test = []
    for i in test_words:
        x_test.append(word_to_index_map.get(i))
    x_test = np.array([x_test])
    print("Indexs: ", x_test)
    test_predictions = model.predict(x_test)
    y_pred = np.argmax(test_predictions[0])
    print("Predictons: ",test_words, " => ", index_to_word_map.get(y_pred))
    print("\n")
# Out:
# Words:  ['we', 'are', 'to', 'study']
# Indexs:  [[ 4  5  6 12]]
# 1/1 [==============================] - 0s 44ms/step
# Predictons:  ['we', 'are', 'to', 'study']  =>  about
#
#
# Words:  ['create', 'programs', 'direct', 'processes']
# Indexs:  [[33 34 35  3]]
# 1/1 [==============================] - 0s 11ms/step
# Predictons:  ['create', 'programs', 'direct', 'processes']  =>  to
#
#
# Words:  ['spirits', 'process', 'study', 'program']
# Indexs:  [[39  8 12 31]]
# 1/1 [==============================] - 0s 12ms/step
# Predictons:  ['spirits', 'process', 'study', 'program']  =>  idea
#
#
# Words:  ['idea', 'study', 'people', 'create']
# Indexs:  [[13 12 32 33]]
# 1/1 [==============================] - 0s 11ms/step
# Predictons:  ['idea', 'study', 'people', 'create']  =>  to
